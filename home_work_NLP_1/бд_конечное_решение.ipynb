# %%
import os

# %%
os.chdir(r"/content/drive/MyDrive/Classroom/ntobdml")

# %%
os.chdir(r"/content/drive/MyDrive/Classroom/ntobdml/строения")

# %%
def clean(text):
  text1=''
  for i in text:
    if ((i==" ")or (i.isalpha())):#isalfa-функция для определения буква ли этот сисмвол или что-то другое
      text1+=i
  text1=text1.lower()
  return text1

# %%
url=os.getcwd()
files=os.listdir(url)
files

# %%
import pandas as pd
text=[]
for i in files:
  with open(i) as f:
    text.append(f.readlines())

# %%
n=0
r=[]
l=[]
for i in range(22):
  for j in range(len(text[i])):
    r.append(text[i][j])

# %%
df=pd.DataFrame(r, columns=["text"])

# %%
df
# Out:
#                                                   text
# 0    Концентрический замок - это замок с двумя или ...
# 1    Концентрические замки напоминают один замок, в...
# 2    Окружающие крепости или города с серией оборон...
# 3    Историки (в частности, Хью Кеннеди) утверждали...
# 4    Хотя концентрический замок имеет двойные стены...
# ..                                                 ...
# 324  Через сто лет Вимаранеш вошёл в состав земель,...
# 325  В дальнейшем замок неоднократно перестраивался...
# 326  В 1383—1385 годах алькальд Гимарайнша, Айриш Г...
# 327  В XV веке замок потерял всякое оборонительное ...
# 328  Замок в плане представляет собой геральдически...
#
# [329 rows x 1 columns]

# %%
df['text_clean']=df['text'].map(lambda x: clean(x))

# %%
os.chdir(r"/content/drive/MyDrive/Classroom/ntobdml/устройства")

# %%
url=os.getcwd()
files=os.listdir(url)
files
# Out:
# ['Детекторный_замок.txt',
#  'Замок_контроля_выхода.txt',
#  'Замок_с_магнитным_ключом.txt',
#  'Защитный замок.txt',
#  'Ригель_замка.txt',
#  'Врезной_замок.txt',
#  'Штифтовой_тумблерный_замок.txt',
#  'Кенсингтонский_замок.txt',
#  'Замок_рулевого_колеса.txt',
#  'Временной_замок.txt',
#  'Багажный_замок.txt',
#  'Одноточечное_запирание.txt',
#  'Цилиндровый_замок.txt',
#  'Замок_Брама.txt',
#  'Замок_для_безопасности_детей.txt',
#  'Замк_и_ключ.txt',
#  'Сувальдный_замок.txt',
#  'Замок_с_нарезкой.txt',
#  'Набор_замков.txt',
#  'Электронный_замок.txt',
#  'Замок_с_картой-ключом.txt',
#  'Умный_замок.txt']

# %%
import pandas as pd
text=[]
for i in files:
  with open(i) as f:
    text.append(f.readlines())

# %%
n=0
r=[]
l=[]
for i in range(22):
  for j in range(len(text[i])):
    r.append(text[i][j])

# %%
df1=pd.DataFrame(r, columns=["text"])

# %%
df1['text_clean']=df1['text'].map(lambda x: clean(x))

# %%
listlock=[]
for predl in df['text_clean']:
  arr=predl.split()
  for i in arr:
    listlock.append(i)

# %%
lock=set(listlock)

# %%
lock

# %%
listlock1=[]
for predl in df1['text_clean']:
  arr=predl.split()
  for i in arr:
    listlock1.append(i)

# %%
castle=set(listlock1)

# %%
castle

# %%
lock

# %%
castle_only=lock-castle
lock_only=castle-lock

# %%
castle_only

# %%
df_cas=pd.DataFrame(castle_only)
df_cas['sum']=0

# %%
df_cas

# %%
t=0
for word in df_cas[0]:
  for predl in df['text_clean']:
    if word in predl:
      df_cas['sum'][t]=1+df_cas['sum'][t]
  t+=1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_cas=df_cas[df_cas['sum']>2]
df_cas=df_cas.reset_index(drop=True)

# %%
df_cas
# Out:
#              0  sum
# 0        расти    6
# 1      толщина    5
# 2          лис   52
# 3         валы    3
# 4          меч    9
# ..         ...  ...
# 792  построены    5
# 793       розы    3
# 794  охотничий    6
# 795    деревню    3
# 796  искусства    5
#
# [797 rows x 2 columns]

# %%
df_cas.to_csv("castle.csv")

# %%
df_lock=pd.DataFrame(lock_only)
df_lock['sum']=0

# %%
t=0
for word in df_lock[0]:
  for predl in df1['text_clean']:
    if word in predl:
      df_lock['sum'][t]=1+df_lock['sum'][t]
  t+=1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_lock=df_lock[df_lock['sum']>2]
df_lock=df_lock.reset_index(drop=True)

# %%
df_lock.to_csv("lock.csv")

# %%
f = open('lock.txt', 'w')
for word in df_lock[0]:
  print(word)
  f.write(word+"\n")

# %%
f = open('castle.txt', 'w')
for word in df_cas[0]:
  print(word)
  f.write(word+"\n")
# Out:
# восстановлению
# расти
# толщина
# диктовал
# подвале
# лис
# трети
# валы
# похода
# меч
# стенах
# летней
# донжон
# двором
# сильное
# хаапсалу
# уничтожил
# командованием
# вильгельм
# продолжили
# герцогов
# городке
# монторгёй
# использовало
# дворец
# пожар
# ними
# приобрёл
# назначен
# подарил
# раскопки
# wa
# пальфи
# слова
# wasserschloss
# la
# периметру
# концентрические
# выпущен
# благо
# третьего
# победителя
# зодчества
# титул
# занял
# карла
# памятников
# ста
# выглядел
# укр
# случаю
# гарнизона
# фортификационных
# старые
# мусульман
# двора
# реку
# имела
# графства
# вёл
# реконструкцию
# сторожевая
# предводитель
# нижняя
# первом
# склады
# украшены
# генерал
# реконкисты
# южном
# ещё
# составлял
# казарм
# холм
# среди
# лично
# короля
# фронтон
# перешейка
# взял
# дуная
# der
# организован
# владения
# деревьев
# одержал
# раньше
# бомарис
# фонтенбло
# сад
# охотничьи
# надёжно
# кат
# владельцами
# жительства
# вв
# сады
# суд
# исключительно
# ...

# %%
os.chdir(r"/content/drive/MyDrive/Classroom/ntobdml")

# %%
s='1047 1072 1084 1086 1082 32 1073 1099 1083 32 1086 1082 1088 1091 1078 1105 1085 32 1073 1086 1083 1100 1096 1080 1084 1080 32 1089 1090 1077 1085 1072 1084 1080 46'
s=s.split()
d={}
stroka=[]
fil = open('cahrtable.txt', encoding='utf-8')
for line in fil:
    d.update({line.split('\t')[0]: line.split('\t')[1][1:2]})

# %%
d

# %%
for i in s:
    stroka += d[i]

# %%
stroka
